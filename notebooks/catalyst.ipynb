# %%
# catalyst ingest-exchange -x bitfinex -f daily -i btc_usd
# catalyst run -f kryptobot/strategies/catalyst/buy_btc_simple.py --start 2015-3-1 --end 2017-10-31 --capital-base 100000 -x bitfinex -c btc -o bah.pickle

# %%
from os import getcwd
import pandas as pd
from kryptobot.portfolio.manager import Manager

config = getcwd() + '/config.json'
manager = Manager(config=config)

params = {
    'strategy': 'buy_btc_simple',
    'capital_base': 10000,
    'data_frequency': 'daily',
    'exchange_name': 'poloniex',
    'algo_namespace': 'buy_btc_simple',
    'quote_currency': 'usdt',
    'start': '2015-03-01',
    'end': '2017-10-31'
}

manager.run_catalyst_strategy(params)

# %%
import pandas as pd
import pickle

data = pd.read_pickle('/usr/src/app/bah.pickle')
data.tail()
# data.head()
# Out:
#                            algo_volatility  algorithm_period_return alpha  \
# 2017-10-27 23:59:00+00:00         0.641613                45.689423  None
# 2017-10-28 23:59:00+00:00         0.641317                45.306729  None
# 2017-10-29 23:59:00+00:00         0.642458                49.483284  None
# 2017-10-30 23:59:00+00:00         0.642144                49.288555  None
# 2017-10-31 23:59:00+00:00         0.642494                52.454894  None
#
#                            benchmark_period_return  benchmark_volatility  \
# 2017-10-27 23:59:00+00:00                 1.641942          1.033202e-17
# 2017-10-28 23:59:00+00:00                 1.644584          1.033202e-17
# 2017-10-29 23:59:00+00:00                 1.647229          1.033201e-17
# 2017-10-30 23:59:00+00:00                 1.649876          1.033201e-17
# 2017-10-31 23:59:00+00:00                 1.652526          1.033200e-17
#
#                            beta     btc  capital_used    ending_cash  \
# 2017-10-27 23:59:00+00:00  None  5759.7  -5771.796522 -923726.362293
# 2017-10-28 23:59:00+00:00  None  5720.3  -5732.313775 -929458.676067
# 2017-10-29 23:59:00+00:00  None  6150.0  -6162.916231 -935621.592298
# 2017-10-30 23:59:00+00:00  None  6130.0  -6142.874227 -941764.466524
# 2017-10-31 23:59:00+00:00  None  6455.1  -6468.657002 -948233.123526
#
#                            ending_exposure           ...            \
# 2017-10-27 23:59:00+00:00        5592668.7           ...
# 2017-10-28 23:59:00+00:00        5560131.6           ...
# 2017-10-29 23:59:00+00:00        5983950.0           ...
# 2017-10-30 23:59:00+00:00        5970620.0           ...
# 2017-10-31 23:59:00+00:00        6293722.5           ...
#
#                            short_exposure  short_value  shorts_count  \
# 2017-10-27 23:59:00+00:00               0            0             0
# 2017-10-28 23:59:00+00:00               0            0             0
# 2017-10-29 23:59:00+00:00               0            0             0
# 2017-10-30 23:59:00+00:00               0            0             0
# 2017-10-31 23:59:00+00:00               0            0             0
#
#                             sortino  starting_cash  starting_exposure  \
# 2017-10-27 23:59:00+00:00  2.944648 -917954.565770          5713300.0
# 2017-10-28 23:59:00+00:00  2.937778 -923726.362293          5592668.7
# 2017-10-29 23:59:00+00:00  2.993485 -929458.676067          5560131.6
# 2017-10-30 23:59:00+00:00  2.989469 -935621.592298          5983950.0
# 2017-10-31 23:59:00+00:00  3.027838 -941764.466524          5970620.0
#
#                            starting_value  trading_days  \
# 2017-10-27 23:59:00+00:00       5713300.0           972
# 2017-10-28 23:59:00+00:00       5592668.7           973
# 2017-10-29 23:59:00+00:00       5560131.6           974
# 2017-10-30 23:59:00+00:00       5983950.0           975
# 2017-10-31 23:59:00+00:00       5970620.0           976
#
#                                                                 transactions  \
# 2017-10-27 23:59:00+00:00  [{'amount': 1, 'dt': 2017-10-27 23:59:00+00:00...
# 2017-10-28 23:59:00+00:00  [{'amount': 1, 'dt': 2017-10-28 23:59:00+00:00...
# 2017-10-29 23:59:00+00:00  [{'amount': 1, 'dt': 2017-10-29 23:59:00+00:00...
# 2017-10-30 23:59:00+00:00  [{'amount': 1, 'dt': 2017-10-30 23:59:00+00:00...
# 2017-10-31 23:59:00+00:00  [{'amount': 1, 'dt': 2017-10-31 23:59:00+00:00...
#
#                            treasury_period_return
# 2017-10-27 23:59:00+00:00                   0.001
# 2017-10-28 23:59:00+00:00                   0.001
# 2017-10-29 23:59:00+00:00                   0.001
# 2017-10-30 23:59:00+00:00                   0.001
# 2017-10-31 23:59:00+00:00                   0.001
#
# [5 rows x 39 columns]
