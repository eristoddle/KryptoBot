# %%
import plotly.plotly as py
import plotly.graph_objs as go
from os import getcwd
from kryptobot.portfolio.manager import Manager

config = getcwd() + '/config.json'
manager = Manager(config=config)
stats = manager.get_last_strategy_results(125)
print(stats)

py.iplot([{
    'x': stats.index,
    'y': stats[col],
    'name': col
}  for col in stats.columns], filename='cufflinks/simple-line')
# Out:
#       base_balance     close  \
# 0              100  0.005723
# 1              100  0.005767
# 2              100  0.005595
# 3                0  0.005262
# 4                0  0.005284
# 5              100  0.005269
# 6              100  0.005241
# 7                0  0.005220
# 8                0  0.005237
# 9                0  0.005869
# 10             100  0.005871
# 11             100  0.005907
# 12             100  0.005907
# 13             100  0.005863
# 14             100  0.005862
# 15             100  0.005855
# 16             100  0.005842
# 17             100  0.005810
# 18             100  0.005796
# 19             100  0.005830
# 20             100  0.005830
# 21             100  0.005820
# 22             100  0.005830
# 23             100  0.005830
# 24             100  0.005796
# 25             100  0.005795
# 26             100  0.005817
# 27             100  0.005818
# 28             100  0.005837
# 29             100  0.005837
# ...            ...       ...
# ...
