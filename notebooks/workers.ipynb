# %%
from kryptobot.portfolio.manager import Manager
manager = Manager()
poc_params = {
    'interval': '5m',
    'exchange': 'bittrex',
    'base_currency': 'NMR',
    'quote_currency': 'BTC',
    'is_simulated': True,
    'fma_periods': 288,
    'sma_periods': 864,
    'sim_balance': 10
}
# manager.run_harvester('harvester', params)
manager.run_strategy('PocStrategy', poc_params)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-673442b73408> in <module>()
# ----> 1 from kryptobot.portfolio.managers import Manager
#       2 manager = Manager()
#       3 poc_params = {
#       4     'interval': '5m',
#       5     'exchange': 'bittrex',
#
# ModuleNotFoundError: No module named 'kryptobot.portfolio.managers'
